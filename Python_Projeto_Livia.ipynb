# %% [markdown]
# <a href="https://colab.research.google.com/github/lsaraiva23/projetopythonfaculdade/blob/main/Python_Projeto_Livia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O UCI Machine Learning Repository é um repositório de conjuntos de dados de aprendizado de máquina que oferece uma ampla variedade de conjuntos de dados, incluindo conjuntos de dados de classificação, regressão, agrupamento, associação, séries temporais e muitos outros. É amplamente utilizado por pesquisadores de todo o mundo para testar algoritmos de aprendizado de máquina, criar modelos e resolver problemas do mundo real.
#
# Um dos conjuntos de dados disponíveis no UCI Machine Learning Repository é o "Image Segmentation Data Set", que contém informações extraídas de imagens digitais de seções transversais de tecidos fotográficos humanos. Este conjunto de dados contém 210 amostras, com 10 amostras por classe, e é frequentemente usado como um exemplo em tarefas de classificação de imagens e visão computacional. As informações contidas no conjunto de dados incluem características relacionadas à intensidade das cores, contrastes e outras medidas da imagem.

# %% [markdown]
# <ul>
# <li>region-centroid-col: a coluna do pixel central da região.</li>
# <li>region-centroid-row: a linha do pixel central da região.</li>
# <li>region-pixel-count: o número de pixels em uma região = 9.</li>
# <li>short-line-density-5: os resultados de um algoritmo de extração de linha que conta quantas linhas de comprimento 5 (qualquer orientação) com baixo contraste, menor ou igual a 5, passam pela região.</li>
# <li>short-line-density-2: o mesmo que short-line-density-5, mas conta as linhas de alto contraste, maiores que 5.</li>
# <li>vedge-mean: mede o contraste dos pixels adjacentes horizontalmente na região. Existem 6 valores, a média e o desvio padrão são fornecidos. Este atributo é usado como detector de borda vertical.</li>
# <li>vedge-sd: desvio padrão de vedge-mean.</li>
# <li>hedge-mean: mede o contraste dos pixels adjacentes verticalmente. Usado para detecção de linhas horizontais.</li>
# <li>hedge-sd: desvio padrão de hedge-mean.</li>
# <li>intensity-mean: a média sobre a região de (R + G + B) / 3.</li>
# <li>rawred-mean: a média sobre a região do valor R.</li>
# <li>rawblue-mean: a média sobre a região do valor B.</li>
# <li>rawgreen-mean: a média sobre a região do valor G.</li>
# <li>exred-mean: mede o excesso de vermelho: (2R - (G + B)).</li>
# <li>exblue-mean: mede o excesso de azul: (2B - (G + R)).</li>
# <li>exgreen-mean: mede o excesso de verde: (2G - (R + B)).</li>
# <li>value-mean: transformação não linear em 3 dimensões do RGB.</li>
# <li>saturation-mean: valor de saturação obtido a partir do valor RGB.</li>
# <li>hue-mean: valor de matiz obtido a partir do valor RGB.</li>
# </ul>

# %%
#importando pacotes
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#carregar os dados
df = pd.read_csv('/content/segmentation.csv')

# %%
#verificando se o df é um data frame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#carregando as 5 primeiras linhas do meu df
df.head()
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# BRICKFACE                   0.0                   0.0    0.277778  0.062963
# BRICKFACE                   0.0                   0.0    0.333333  0.266667
# BRICKFACE                   0.0                   0.0    0.277778  0.107407
# BRICKFACE                   0.0                   0.0    0.500000  0.166667
# BRICKFACE                   0.0                   0.0    0.722222  0.374074
#
# ...

# %%
#nome das minhas colunas
df.columns
# Out:
# Index(['REGION-CENTROID-COL', 'REGION-CENTROID-ROW', 'REGION-PIXEL-COUNT',
#        'SHORT-LINE-DENSITY-5', 'SHORT-LINE-DENSITY-2', 'VEDGE-MEAN',
#        'VEDGE-SD', 'HEDGE-MEAN', 'HEDGE-SD', 'INTENSITY-MEAN', 'RAWRED-MEAN',
#        'RAWBLUE-MEAN', 'RAWGREEN-MEAN', 'EXRED-MEAN', 'EXBLUE-MEAN',
#        'EXGREEN-MEAN', 'VALUE-MEAN', 'SATURATION-MEAN', 'HUE-MEAN'],
#       dtype='object')

# %%
#verificando o tipo de dados em cada coluna e os dados vazios
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210 entries, BRICKFACE to GRASS
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   REGION-CENTROID-COL   210 non-null    float64
#  1   REGION-CENTROID-ROW   210 non-null    float64
#  2   REGION-PIXEL-COUNT    210 non-null    int64
#  3   SHORT-LINE-DENSITY-5  210 non-null    float64
#  4   SHORT-LINE-DENSITY-2  210 non-null    float64
#  5   VEDGE-MEAN            210 non-null    float64
#  6   VEDGE-SD              210 non-null    float64
#  7   HEDGE-MEAN            210 non-null    float64
#  8   HEDGE-SD              210 non-null    float64
#  9   INTENSITY-MEAN        210 non-null    float64
#  10  RAWRED-MEAN           210 non-null    float64
#  11  RAWBLUE-MEAN          210 non-null    float64
#  12  RAWGREEN-MEAN         210 non-null    float64
#  13  EXRED-MEAN            210 non-null    float64
# ...

# %%
#fazendo a análise exploratória
df.describe()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count           210.000000           210.000000               210.0
# mean            124.647619           122.757143                 9.0
# std              74.104024            58.139686                 0.0
# min               1.000000            11.000000                 9.0
# 25%              60.500000            81.500000                 9.0
# 50%             123.500000           121.500000                 9.0
# 75%             189.750000           174.500000                 9.0
# max             252.000000           250.000000                 9.0
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  \
# count            210.000000            210.000000  210.000000  210.000000
# mean               0.008466              0.006349    1.925132    5.719529
# std                0.029549              0.030077    3.158211   43.495942
# ...

# %%
#escolhi uma caracteristica e excluir os valores zerados da base
df = df[df['SHORT-LINE-DENSITY-5'] != 0]
df
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                 26.0                 67.0                   9
# SKY                        8.0                 39.0                   9
# SKY                      125.0                 46.0                   9
# FOLIAGE                  101.0                121.0                   9
# CEMENT                    14.0                146.0                   9
# CEMENT                   141.0                 17.0                   9
# PATH                      86.0                197.0                   9
# PATH                      87.0                196.0                   9
# PATH                     182.0                186.0                   9
# GRASS                     71.0                180.0                   9
# GRASS                     60.0                181.0                   9
# GRASS                    233.0                211.0                   9
# ...

# %%
#fazendo o histograma sem os zeros da coluna 'SHORT-LINE-DENSITY-5'
df.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# ## Conclusão
#
# A partir da análise do Image Segmentation Data Set, algumas conclusões podem ser tiradas:
#
# A maioria das regiões contém 9 pixels, como indicado pelo atributo "region-pixel-count".
#
# Os valores médios das intensidades de cor (R, G e B) são relativamente semelhantes em todas as regiões, enquanto as médias de "excess red", "excess blue" e "excess green" variam mais entre as regiões.
#
# A maioria das regiões não possui linhas de baixo contraste com comprimento 5, como indicado pelo atributo "short-line-density-5".
#
# A maioria das regiões possui um valor médio de saturação de cerca de 31-32, como indicado pelo atributo "saturation-mean".
#
# Os valores médios de "value" e "hue" variam consideravelmente entre as regiões.
